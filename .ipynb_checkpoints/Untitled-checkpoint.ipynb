# %%
import numpy as np
import cv2 as cv
from matplotlib import pyplot as plt
MIN_MATCH_COUNT = 10
img1 = cv.imread('Screen/current.jpg', cv.IMREAD_GRAYSCALE)          # queryImage
img2 = cv.imread('Screen/previous.jpg', cv.IMREAD_GRAYSCALE)         # trainImage
img1 = cv.Canny(img1,300,500)
img2 = cv.Canny(img2,300,500)
# Initiate SIFT detector
sift = cv.SIFT_create()
# find the keypoints and descriptors with SIFT
kp1, des1 = sift.detectAndCompute(img1,None)
kp2, des2 = sift.detectAndCompute(img2,None)
FLANN_INDEX_KDTREE = 1
index_params = dict(algorithm = FLANN_INDEX_KDTREE, trees = 5)
search_params = dict(checks = 50)
flann = cv.FlannBasedMatcher(index_params, search_params)
matches = flann.knnMatch(des1,des2,k=2)
# store all the good matches as per Lowe's ratio test.
good = []
for m,n in matches:
    if m.distance < 1*n.distance:
        good.append(m)

# %%
src_pts = None
dst_pts = None
if len(good)>MIN_MATCH_COUNT:
    src_pts = np.float32([ kp1[m.queryIdx].pt for m in good ]).reshape(-1,1,2)
    dst_pts = np.float32([ kp2[m.trainIdx].pt for m in good ]).reshape(-1,1,2)
    M, mask = cv.findHomography(src_pts, dst_pts, cv.RANSAC,5.0)
    matchesMask = mask.ravel().tolist()
    h,w = img1.shape
    pts = np.float32([ [0,0],[0,h-1],[w-1,h-1],[w-1,0] ]).reshape(-1,1,2)
    dst = cv.perspectiveTransform(pts,M)
    img2 = cv.polylines(img2,[np.int32(dst)],True,255,3, cv.LINE_AA)
else:
    print( "Not enough matches are found - {}/{}".format(len(good), MIN_MATCH_COUNT) )
    matchesMask = None

# %%
draw_params = dict(matchColor = (0,255,0), # draw matches in green color
                   singlePointColor = None,
                   matchesMask = matchesMask, # draw only inliers
                   flags = 2)
img3 = cv.drawMatches(img1,kp1,img2,kp2,good,None,**draw_params)
plt.imshow(img3, 'gray'),plt.show()
# Out:
# (<matplotlib.image.AxesImage at 0x2689e0acdd0>, None)

# %%
src_array = src_pts.reshape(-1, 1)
dst_array = dst_pts.reshape(-1)
length = src_array.shape[0] // 2
extra1 = np.array([[1, 0]]).repeat(length, axis=0).reshape(-1, 1)
extra2 = np.array([[0, 1]]).repeat(length, axis=0).reshape(-1, 1)
equM = np.hstack((src_array, extra1, extra2))
# matrix multiplication
M = np.matmul(np.transpose(equM), equM)
X = np.matmul(np.transpose(equM), dst_array)
# solve the equation
a, b, c = np.linalg.solve(M, X)
print(a, b, c)
# Out:
# 0.11539298014149392 47.39008989961947 60.34130271926359

# %%
draw_params = dict(matchColor = (0,255,0), # draw matches in green color
                   singlePointColor = None,
                   flags = 2)
img3 = cv.drawMatches(img1,kp1,img2,kp2,good,None,**draw_params)
plt.imshow(img3, 'gray'),plt.show()
# Out:
# (<matplotlib.image.AxesImage at 0x2689e112210>, None)

# %%
import numpy as np
import cv2 as cv
from matplotlib import pyplot as plt
img1 = cv.imread('Screen/previous.jpg', cv.IMREAD_GRAYSCALE)
img2 = cv.imread('Screen/current.jpg', cv.IMREAD_GRAYSCALE)
assert img1 is not None, "file1 could not be read, check with os.path.exists()"
assert img2 is not None, "file2 could not be read, check with os.path.exists()"
edges1 = cv.Canny(img1,300,500)
edges2 = cv.Canny(img2,300,500)
plt.subplot(221),plt.imshow(img1,cmap = 'gray')
plt.title('Original Image'), plt.xticks([]), plt.yticks([])
plt.subplot(222),plt.imshow(edges1,cmap = 'gray')
plt.title('Edge Image'), plt.xticks([]), plt.yticks([])
plt.subplot(223),plt.imshow(img2,cmap = 'gray')
plt.title('Original Image'), plt.xticks([]), plt.yticks([])
plt.subplot(224),plt.imshow(edges2,cmap = 'gray')
plt.title('Edge Image'), plt.xticks([]), plt.yticks([])
# Out:
# (Text(0.5, 1.0, 'Edge Image'), ([], []), ([], []))

# %%
valueMax = 0
size = edges1.shape
for i in range(21):
    scale = 0.9 + i * 0.01
    test1 = edges1.astype(np.float64)
    test2 = edges2.astype(np.float64)
    shift = (1 - scale) * size / 2
    test1 = cv.warpAffine(test1, np.float32([[scale,0,shift[0]],[0,scale,shift[1]]]),(size[0],size[1]))
    test2 = cv.warpAffine(test2, np.float32([[1,0,0],[0,1,0]]),(size[0],size[1]))
    offset, value = cv.phaseCorrelate(test1, test2)
    print(offset, value)
    if value > valueMax:
        valueMax = value
        final1 = test1
        final2 = test2
        res = cv.warpAffine(test1, np.float32([[1,0,offset[0]],[0,1,offset[1]]]),(size[0],size[1]))
plt.subplot(131),plt.imshow(final1,cmap = 'gray')
plt.subplot(132),plt.imshow(final2,cmap = 'gray')
plt.subplot(133),plt.imshow(res - final2,cmap = 'gray')
print(value)
# Out:
# (-7.126389754349347, 12.261064654633678) 0.30338052816684963
# (-6.788849484305672, 9.36370625661683) 0.37215052992949665
# (-7.610592236412472, 9.10690854688091) 0.30916443348217443
# (-7.906445132855623, 7.702138362454967) 0.34212427791157474
# (-7.0537508284552075, 5.230443657092167) 0.6624743614257163
# (-7.165780913813904, 4.298690418708738) 0.6973955762157152
# (-8.247574583197022, 3.916647272701489) 0.6197858279804772
# (-8.556778447684522, 3.315303536727697) 0.6672184376374515
# (-8.69725076908999, 2.4295294359321105) 0.729149877108501
# (-9.528788244167188, 2.1815316613890303) 0.6875718927564822
# (-10.212514586542369, 1.4815739334555076) 0.6423234517197607
# (-10.442036950679551, 0.6889439228418297) 0.6222788395429183
# (-10.924774719248958, 0.22189772011202535) 0.612335679393002
# (-11.55236077497284, -0.5206706631798994) 0.6258860022161256
# (-11.796797863538004, -1.2958488134676145) 0.6400113921971154
# (-12.739443980318299, -1.8510268647939654) 0.5969273412569784
# (-12.250700646613367, -3.8234975793765926) 0.4134851484737153
# (-12.622672817779716, -5.066057748323161) 0.3501383278533199
# (-12.681526960199491, -6.172821121974977) 0.26419115473971966
# (-13.556206932679501, -6.182936484124653) 0.3192022022544294
# (-13.945363029770988, -7.358094893012591) 0.14602959489316622
# 0.14602959489316622
